# %%
import pandas as pd

# %%
dados = {
    "produto": ["Notebook", "Mouse", "Teclado"],
    "vendas": [15, 50, 30]
}

# %%
df = pd.DataFrame(dados)

# %%
print(df)
# Out:
#     produto  vendas
# 0  Notebook      15
# 1     Mouse      50
# 2   Teclado      30
